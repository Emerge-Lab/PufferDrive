# %%
import torch
import torch.nn as nn

# %%
a = torch.ones(2, 6, 7)

# %%
bb = torch.split(a, [4, 2], dim=1)

# %%
bb[0].shape

# %%
bb[1].shape

# %%
b = torch.ones(2, 15)
c = b.reshape((2, 3, 5))

# %%
c.shape
